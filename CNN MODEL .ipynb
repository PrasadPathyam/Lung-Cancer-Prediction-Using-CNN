# %%
import tensorflow.keras
from tensorflow.keras import layers
from tensorflow.keras import Model 
from tensorflow.keras.models import Sequential
from tensorflow.keras.preprocessing import image
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications.vgg16 import VGG16, preprocess_input
from tensorflow.keras.models import load_model, Model
from tensorflow.keras.layers import Dense,Conv2D, Flatten, MaxPool2D, Dropout

# %%
import os
import cv2
import pandas as pd
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings("ignore")

# %%
train_path = (r"C:\Users\Admin\Downloads\archive\Data\train")
val_path = (r"C:\Users\Admin\Downloads\archive\Data\valid")
test_path = (r"C:\Users\Admin\Downloads\archive\Data\test")

# %%
def GetDatasetSize(path):
    num_of_image = {}
    for folder in os.listdir(path):
        # Counting the Number of Files in the Folder
        num_of_image[folder] = len(os.listdir(os.path.join(path, folder)));
    return num_of_image;
    
train_set = GetDatasetSize(train_path)
val_set = GetDatasetSize(val_path)
test_set = GetDatasetSize(test_path)
print(train_set,"\n\n",val_set,"\n\n",test_set)
# Out:
# {'adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib': 195, 'large.cell.carcinoma_left.hilum_T2_N2_M0_IIIa': 115, 'normal': 148, 'squamous.cell.carcinoma_left.hilum_T1_N2_M0_IIIa': 155}
#
#  {'adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib': 23, 'large.cell.carcinoma_left.hilum_T2_N2_M0_IIIa': 21, 'normal': 13, 'squamous.cell.carcinoma_left.hilum_T1_N2_M0_IIIa': 15}
#
#  {'adenocarcinoma': 120, 'large.cell.carcinoma': 51, 'normal': 54, 'squamous.cell.carcinoma': 90}

# %%
labels = ['squamous.cell.carcinoma', 'normal', 'adenocarcinoma', 'large.cell.carcinoma']
train_list = list(train_set.values())
val_list = list(val_set.values())
test_list = list(test_set.values())

x = np.arange(len(labels))  # the label locations
width = 0.25  # the width of the bars

fig, ax = plt.subplots()
rects1 = ax.bar(x - width, train_list, width, label='Train')
rects2 = ax.bar(x, val_list, width, label='Val')
rects3 = ax.bar(x + width, test_list, width, label='Test')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('Images Count')
ax.set_title('Dataset')
ax.set_xticks(x, labels)
plt.xticks(rotation=15)
ax.legend()

ax.bar_label(rects1)
ax.bar_label(rects2)
ax.bar_label(rects3)

fig.tight_layout()

plt.show()

# %%
train_datagen = ImageDataGenerator(rescale = 1.0/255.0,
                                  horizontal_flip = True,
                                  fill_mode = 'nearest',
                                  zoom_range=0.2,
                                  shear_range = 0.2,
                                  width_shift_range=0.2,
                                  height_shift_range=0.2,
                                  rotation_range=0.4)

train_data = train_datagen.flow_from_directory(train_path,
                                                   batch_size = 5,
                                                   target_size = (350,350),
                                                   class_mode = 'categorical')
# Out:
# Found 613 images belonging to 4 classes.

# %%
train_data.class_indices
# Out:
# {'adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib': 0,
#  'large.cell.carcinoma_left.hilum_T2_N2_M0_IIIa': 1,
#  'normal': 2,
#  'squamous.cell.carcinoma_left.hilum_T1_N2_M0_IIIa': 3}

# %%
val_datagen = ImageDataGenerator(rescale = 1.0/255.0)
val_data = val_datagen.flow_from_directory(val_path,
                                                   batch_size = 5,
                                                   target_size = (350,350),
                                                   class_mode = 'categorical')
# Out:
# Found 72 images belonging to 4 classes.

# %%
val_data.class_indices
# Out:
# {'adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib': 0,
#  'large.cell.carcinoma_left.hilum_T2_N2_M0_IIIa': 1,
#  'normal': 2,
#  'squamous.cell.carcinoma_left.hilum_T1_N2_M0_IIIa': 3}

# %%
test_datagen = ImageDataGenerator(rescale = 1.0/255.0)
test_data = test_datagen.flow_from_directory(test_path,
                                                   batch_size = 5,
                                                   target_size = (350,350),
                                                   class_mode = 'categorical')
# Out:
# Found 315 images belonging to 4 classes.

# %%
test_data.class_indices
# Out:
# {'adenocarcinoma': 0,
#  'large.cell.carcinoma': 1,
#  'normal': 2,
#  'squamous.cell.carcinoma': 3}

# %% [markdown]
# # CNN MODEL

# %%
model = Sequential() 

# Convolutional Layer with input shape (350,350,3)
model.add(Conv2D(filters=32, kernel_size= (3,3), activation= 'relu', input_shape=(350,350,3)) )

model.add(Conv2D(filters=32, kernel_size=(3,3), activation='relu' ))
model.add(MaxPool2D(pool_size=(2,2)))

model.add(Conv2D(filters=64, kernel_size=(3,3), activation='relu' ))
model.add(MaxPool2D(pool_size=(2,2)))

model.add(Conv2D(filters=128, kernel_size=(3,3), activation='relu' ))
model.add(MaxPool2D(pool_size=(2,2)))

model.add(Dropout(rate=0.25))

model.add(Flatten())
model.add(Dense(units=64, activation='relu'))
model.add(Dropout(rate=0.25))
model.add(Dense(units=4, activation='sigmoid'))

model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy']  )
 
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 348, 348, 32)   │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 346, 346, 32)   │         9,248 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 173, 173, 32)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 171, 171, 64)   │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 85, 85, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_3 (Conv2D)               │ (None, 83, 83, 128)    │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 41, 41, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 41, 41, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 215168)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 64)             │    13,770,816 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 4)              │           260 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 13,873,572 (52.92 MB)
#  Trainable params: 13,873,572 (52.92 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
from keras.callbacks import ModelCheckpoint

# Adding Model checkpoint Callback
mc = ModelCheckpoint(
    filepath="./ct_cnn_best_model.keras",  # Changed to .keras
    monitor='val_accuracy',
    verbose=1,
    save_best_only=True,
    mode='auto'
)

call_back = [mc]

# %%
# Fitting the Model
cnn = model.fit(
    train_data, 
    steps_per_epoch = train_data.samples//train_data.batch_size, 
    epochs = 20, 
    validation_data = val_data, 
    validation_steps = val_data.samples//val_data.batch_size,
    callbacks = call_back
    )
# Out:
# Epoch 1/20
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 983ms/step - accuracy: 0.3176 - loss: 1.4427
# Epoch 1: val_accuracy improved from -inf to 0.50000, saving model to ./ct_cnn_best_model.keras
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 130s 1s/step - accuracy: 0.3183 - loss: 1.4413 - val_accuracy: 0.5000 - val_loss: 1.1570
# Epoch 2/20
#   1/122 ━━━━━━━━━━━━━━━━━━━━ 3:11 2s/step - accuracy: 0.8000 - loss: 0.4923
# Epoch 2: val_accuracy did not improve from 0.50000
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8000 - loss: 0.4923 - val_accuracy: 0.5000 - val_loss: 1.3500
# Epoch 3/20
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 955ms/step - accuracy: 0.3674 - loss: 1.3773
# Epoch 3: val_accuracy did not improve from 0.50000
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 120s 978ms/step - accuracy: 0.3678 - loss: 1.3764 - val_accuracy: 0.5000 - val_loss: 1.0741
# Epoch 4/20
#   1/122 ━━━━━━━━━━━━━━━━━━━━ 1:57 971ms/step - accuracy: 0.6000 - loss: 0.7441
# Epoch 4: val_accuracy did not improve from 0.50000
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 949us/step - accuracy: 0.6000 - loss: 0.7441 - val_accuracy: 0.0000e+00 - val_loss: 1.1849
# Epoch 5/20
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 950ms/step - accuracy: 0.4681 - loss: 1.1228
# Epoch 5: val_accuracy did not improve from 0.50000
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 119s 974ms/step - accuracy: 0.4680 - loss: 1.1230 - val_accuracy: 0.4571 - val_loss: 1.0859
# Epoch 6/20
#   1/122 ━━━━━━━━━━━━━━━━━━━━ 2:09 1s/step - accuracy: 0.6000 - loss: 1.4168
# Epoch 6: val_accuracy did not improve from 0.50000
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.6000 - loss: 1.4168 - val_accuracy: 0.5000 - val_loss: 1.2344
# Epoch 7/20
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 948ms/step - accuracy: 0.4642 - loss: 1.1522
# Epoch 7: val_accuracy did not improve from 0.50000
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 119s 970ms/step - accuracy: 0.4643 - loss: 1.1524 - val_accuracy: 0.5000 - val_loss: 1.0685
# Epoch 8/20
#   1/122 ━━━━━━━━━━━━━━━━━━━━ 1:58 979ms/step - accuracy: 0.8000 - loss: 0.7831
# Epoch 8: val_accuracy did not improve from 0.50000
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.8000 - loss: 0.7831 - val_accuracy: 0.5000 - val_loss: 0.7356
# Epoch 9/20
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 905ms/step - accuracy: 0.4750 - loss: 1.0904
# Epoch 9: val_accuracy did not improve from 0.50000
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 113s 927ms/step - accuracy: 0.4751 - loss: 1.0905 - val_accuracy: 0.4857 - val_loss: 1.0071
# Epoch 10/20
#   1/122 ━━━━━━━━━━━━━━━━━━━━ 2:04 1s/step - accuracy: 0.6000 - loss: 1.0472
# Epoch 10: val_accuracy did not improve from 0.50000
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.6000 - loss: 1.0472 - val_accuracy: 0.5000 - val_loss: 1.2142
# Epoch 11/20
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.4948 - loss: 1.0582
# Epoch 11: val_accuracy did not improve from 0.50000
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 125s 1s/step - accuracy: 0.4948 - loss: 1.0582 - val_accuracy: 0.4143 - val_loss: 0.9811
# Epoch 12/20
#   1/122 ━━━━━━━━━━━━━━━━━━━━ 1:58 981ms/step - accuracy: 0.4000 - loss: 1.6926
# Epoch 12: val_accuracy did not improve from 0.50000
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.4000 - loss: 1.6926 - val_accuracy: 0.5000 - val_loss: 1.1231
# Epoch 13/20
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.5168 - loss: 1.0108
# Epoch 13: val_accuracy did not improve from 0.50000
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 145s 1s/step - accuracy: 0.5169 - loss: 1.0107 - val_accuracy: 0.5000 - val_loss: 1.0023
# Epoch 14/20
#   1/122 ━━━━━━━━━━━━━━━━━━━━ 2:42 1s/step - accuracy: 0.8000 - loss: 0.6125
# Epoch 14: val_accuracy did not improve from 0.50000
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.8000 - loss: 0.6125 - val_accuracy: 0.5000 - val_loss: 0.8690
# Epoch 15/20
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.4805 - loss: 1.0181
# Epoch 15: val_accuracy improved from 0.50000 to 0.51429, saving model to ./ct_cnn_best_model.keras
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 173s 1s/step - accuracy: 0.4806 - loss: 1.0180 - val_accuracy: 0.5143 - val_loss: 0.9690
# Epoch 16/20
#   1/122 ━━━━━━━━━━━━━━━━━━━━ 2:42 1s/step - accuracy: 0.6000 - loss: 0.5303
# Epoch 16: val_accuracy did not improve from 0.51429
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.6000 - loss: 0.5303 - val_accuracy: 0.0000e+00 - val_loss: 1.5743
# Epoch 17/20
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.5248 - loss: 0.9793
# Epoch 17: val_accuracy did not improve from 0.51429
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 155s 1s/step - accuracy: 0.5247 - loss: 0.9795 - val_accuracy: 0.4857 - val_loss: 0.9542
# Epoch 18/20
#   1/122 ━━━━━━━━━━━━━━━━━━━━ 2:37 1s/step - accuracy: 0.4000 - loss: 1.2447
# Epoch 18: val_accuracy improved from 0.51429 to 1.00000, saving model to ./ct_cnn_best_model.keras
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.4000 - loss: 1.2447 - val_accuracy: 1.0000 - val_loss: 0.9038
# Epoch 19/20
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.5118 - loss: 0.9593
# Epoch 19: val_accuracy did not improve from 1.00000
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 158s 1s/step - accuracy: 0.5118 - loss: 0.9594 - val_accuracy: 0.4857 - val_loss: 0.9597
# Epoch 20/20
#   1/122 ━━━━━━━━━━━━━━━━━━━━ 2:36 1s/step - accuracy: 0.6000 - loss: 0.9318
# Epoch 20: val_accuracy did not improve from 1.00000
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.6000 - loss: 0.9318 - val_accuracy: 1.0000 - val_loss: 0.5069

# %%
# Loading the Best Fit Model 
model = load_model("./ct_cnn_best_model.keras")

# %%
# Checking the Accuracy of the Model
accuracy_cnn = model.evaluate(test_data)[1]  # use evaluate instead of evaluate_generator
print(f"The accuracy of the model is = {accuracy_cnn * 100} %")
# Out:
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 12s 183ms/step - accuracy: 0.5895 - loss: 0.9200
# The accuracy of the model is = 55.23809790611267 %

# %%
cnn.history.keys()
# Out:
# dict_keys(['accuracy', 'loss', 'val_accuracy', 'val_loss'])

# %%
# Plot model performance
acc = cnn.history['accuracy']
val_acc = cnn.history['val_accuracy']
loss = cnn.history['loss']
val_loss = cnn.history['val_loss']
epochs_range = range(1, len(cnn.epoch) + 1)

plt.figure(figsize=(15,5))

plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Train Set')
plt.plot(epochs_range, val_acc, label='Val Set')
plt.legend(loc="best")
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.title('Model Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Train Set')
plt.plot(epochs_range, val_loss, label='Val Set')
plt.legend(loc="best")
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Model Loss')

plt.tight_layout()
plt.show()
